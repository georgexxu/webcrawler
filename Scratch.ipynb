# %%
# %load_ext autoreload
# %autoreload 2
import argparse
from csv import DictWriter
import json
import sys

from bs4 import BeautifulSoup
import urllib.request as request

# %%
def getHTML(url):
    headers = {'User-Agent': 'User-Agent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'}
    req = request.Request(url, headers=headers)
    return request.urlopen(req).read()

# %%
url = "https://www.openrice.com/en/hongkong/restaurants?what=fish"

# %%
soup = BeautifulSoup(getHTML(url), 'lxml')

# %%
jsonUrl = 'https://www.openrice.com/api/pois?uiLang=en&uiCity=hongkong&page=1&&sortBy=Default&categoryGroupId=10002&categoryGroupId=20002'

# %%
soup = BeautifulSoup(getHTML(jsonUrl), 'lxml')

# %%
data = json.loads(getHTML(jsonUrl))

# %%
data
# Out:
# {'baseUrl': '/en/hongkong/restaurants?categoryGroupId=10002&categoryGroupId=20002',
#  'closedPoiCount': 0,
#  'desktopPagination': {'currentUrl': '/en/hongkong/restaurants?categoryGroupId=10002&categoryGroupId=20002',
#   'isNoResult': False,
#   'next': {'isNext': True,
#    'isPrev': False,
#    'page': 2,
#    'url': '/en/hongkong/restaurants?categoryGroupId=10002&categoryGroupId=20002&page=2'},
#   'paginations': [{'isNext': False,
#     'isPrev': False,
#     'page': 1,
#     'url': '/en/hongkong/restaurants?categoryGroupId=10002&categoryGroupId=20002'},
#    {'isNext': True,
#     'isPrev': False,
#     'page': 2,
#     'url': '/en/hongkong/restaurants?categoryGroupId=10002&categoryGroupId=20002&page=2'},
#    {'isNext': True,
#     'isPrev': False,
#     'page': 3,
#     'url': '/en/hongkong/restaurants?categoryGroupId=10002&categoryGroupId=20002&page=3'},
#    {'isNext': True,
#     'isPrev': False,
#     'page': 4,
# ...

# %%
data['baseUrl']
# Out:
# '/en/hongkong/restaurants?categoryGroupId=10002&categoryGroupId=20002'

# %%
data['searchResult']['paginationResult']['results'][0]
# Out:
# {'address': 'Shop L, 4/F, Phase 3, Kwun Tong Industrial Centre, 436-484 Kwun Tong Road',
#  'addressLangIndex': 2,
#  'addressOtherLang': '觀塘道436-484號官塘工業中心3期4樓L室',
#  'addressOtherLangIndex': 1,
#  'addressUI': {'plainAddress': '\r\nShop L, 4/F, Phase 3, Kwun Tong Industrial Centre, 436-484 Kwun Tong Road, Kwun Tong\r\n',
#   'richAddress': '\r\nShop L, 4/F, Phase 3, Kwun Tong Industrial Centre, 436-484 Kwun Tong Road, <a href="/en/hongkong/restaurants/district/kwun-tong">Kwun Tong</a>\r\n'},
#  'awardStatus': 0,
#  'bankPromotionsUI': [],
#  'bookmarkedCategories': [],
#  'bookmarkedUserCount': 4152,
#  'bookmarkedUserUI': {'amlMembershipNo': 0,
#   'bookmarkedOfferCount': 0,
#   'bookmarkedRestaurantCount': 0,
#   'bookmarkedVoucherCount': 0,
#   'editorChoiceReviewCount': 0,
#   'email': '',
#   'eventCount': 0,
#   'facebookId': 0,
#   'fanCount': 0,
#   'fullname': '',
#   'googleId': '',
#   'hasPhoto': 0,
#   'hitCount': 0,
#   'idolCount': 0,
#   'isFollowed': False,
# ...

# %%
url = "https://www.openrice.com/en/hongkong/r-%E6%A6%AE%E5%93%A5%E5%BB%9A%E6%88%BF%E7%A7%81%E6%88%BF%E8%8F%9C-kwun-tong-international-r510459/reviews"
soup = BeautifulSoup(getHTML(url), 'lxml')

# %%
review_list = [e for e in soup.find_all('section', {'class':"review-container"})]
review_list = []
for e in soup.find_all('section', {'class':"review-container"}):
    [x.extract() for x in e.find_all('a')]
    review_list.append("".join(e.stripped_strings))
# review_list = [e.text for e in soup.find_all('section', {'class':"review-container"})]

# %%
print (review_list[0])
# Out:
# 早前在網上見到有篇報道說有些網絡紅人在live播片時錯手關了美顏，真身嚇壞很多人，其實不單女士有喬妝，在近年的尋食經驗中也發現很多時我們都會被照騙影響。食評可以是假，你以為照片不能騙人？那就錯了，同一間食店同一款食物，影到鬆郁濛和用filter令相片顏色更濃艷相比，後者一定更能吸引你光顧。也是這個原因，即使我很早之前已經聽過榮哥這個名字，但因為看過食物相片不特別吸引所以一直沒有光顧。但當聽到不止一個朋友大力推介，又開始掀動我的好奇心，我決定俾次機會佢。＊＊＊＊＊＊＊＊＊＊＊榮哥是一間中式私房菜，店內全部是中式圓枱。由於是私房菜，所以食店沒有餐牌，通常都是預先訂位和事前跟食店溝通好菜單。食單有幾個菜單選擇，如果有甚麼不吃的，可再稍作改動，收費亦如其他私房菜般按人頭收費。一入門口就會見到幾個主廚榮哥的獎牌和獎杯。另一樣吸引我目光的，就是這一排水耕菜，全部都開得非常茂盛和翠綠。今次我們的菜單包括四款前菜、燉湯、五道菜、炒飯和鮮果拼盤，人頭$338，價位非常合理。有機沙律醬伴芝麻醬這個沙律菜真是超過新鮮爽脆，原來就是門口位的水耕菜，當然店內的水耕菜沒可能足夠應付客人需要，但貨源是來自同一處的，侍者解釋只有不夠菜時才會用店內的水耕菜應急。本身生菜夠新鮮爽脆已經不會差得去那裡，而車厘茄微酸中還帶點鮮甜，再加上芝麻醬，非常美味。紫薯配鮮淮山紫薯和鮮淮山都切成小丁方，紫薯清甜，淮山有沙沙口感，沒有調味，能吃出食材原有的味道。涼拌伴黑木耳黑木耳很爽口，入口微涼，只簡單加上麻油調味已經味道不錯。茶燻流心蛋伴黑魚子醬配厚切茄子厚切茄子上放上半隻流心蛋，流心蛋因為經過茶葉燻過，所以外層呈淺啡色。流心蛋只有蛋黃最中間部份呈半固體狀，邊位都是蛋汁，食落蛋香豐富亦帶點茶葉清香味，下面的茄子煮得很軟腍，吸收了碟底的芡汁，簡直冇得輸。原盡燉姬松茸淮山燉甘筍黑毛豚肉湯燉湯捧上時熱辣辣，入面非常足料，有姬松茸、淮山、龍眼肉、螺頭、紅蘿蔔和豬肉，燉得夠入味，姬松茸據聞有保護肝腎之效，平時習慣夜訓的人飲就最適合。原盅燉品蜜瓜螺頭黑毛豚肉湯燉湯內有蜜瓜、龍眼肉、螺頭和豬肉，飲落味道其實跟姬松茸燉湯差不多，但因有蜜瓜，所以味道較清甜，所以兩款燉湯之中個人亦比較偏好這一款。蝦球水芙蓉水芙蓉就是蒸蛋白，上面以高湯製成的芡汁令蛋白鋪上一層金黃色，賣相度大增，面層再放上三隻蝦球和炸薑絲。蛋白非常滑溜。蝦球肉質爽彈結
# ...

# %%
print (len(review_list), type(review_list[0]))
str(review_list[0])
# Out:
# 15 <class 'str'>
# ...

# %%
type(review_list[0].text)
review_list[0].text
# Out:
# '\r\n                早前在網上見到有篇報道說有些網絡紅人在live播片時錯手關了美顏，真身嚇壞很多人，其實不單女士有喬妝，在近年的尋食經驗中也發現很多時我們都會被照騙影響。食評可以是假，你以為照片不能騙人？那就錯了，同一間食店同一款食物，影到鬆郁濛和用filter令相片顏色更濃艷相比，後者一定更能吸引你光顧。也是這個原因，即使我很早之前已經聽過榮哥這個名字，但因為看過食物相片不特別吸引所以一直沒有光顧。但當聽到不止一個朋友大力推介，又開始掀動我的好奇心，我決定俾次機會佢。＊＊＊＊＊＊＊＊＊＊＊榮哥是一間中式私房菜，店內全部是中式圓枱。由於是私房菜，所以食店沒有餐牌，通常都是預先訂位和事前跟食店溝通好菜單。食單有幾個菜單選擇，如果有甚麼不吃的，可再稍作改動，收費亦如其他私房菜般按人頭收費。一入門口就會見到幾個主廚榮哥的獎牌和獎杯。另一樣吸引我目光的，就是這一排水耕菜，全部都開得非常茂盛和翠綠。今次我們的菜單包括四款前菜、燉湯、五道菜、炒飯和鮮果拼盤，人頭$338，價位非常合理。有機沙律醬伴芝麻醬這個沙律菜真是超過新鮮爽脆，原來就是門口位的水耕菜，當然店內的水耕菜沒可能足夠應付客人需要，但貨源是來自同一處的，\r\n                \nRead full review\n\n\n\n\n'

# %%
user_list = [e.text for e in soup.find_all('a', {'itemprop':"author"})]

# %%
user_list
len(user_list)
type(user_list)
# Out:
# list

# %%
type(user_list[0])
# Out:
# str

# %%
user_list
# Out:
# ['tht_dawn',
#  'waynecfc',
#  'sonsondi',
#  'hiuytsang8',
#  'magic-patrick',
#  'konim',
#  '11號巴士',
#  'ILoveEating82',
#  'key1125hk',
#  'charmaine728',
#  'ho.ruru',
#  'zackhung',
#  'carykof',
#  'feifeiwoo',
#  'wlamkc']

# %%
user_name = 'jerry_jiarui_xu'
password = 'xvjiarui'

api = Client(user_name, password)
results = api.feed_timeline()
items = [item for item in results.get('feed_items', [])
         if item.get('media_or_ad')]
for item in items:
    # Manually patch the entity to match the public api as closely as possible, optional
    # To automatically patch entities, initialise the Client with auto_patch=True
    ClientCompatPatch.media(item['media_or_ad'])
    print(item['media_or_ad']['code'])
# Out:
# BcNCU6xBr8csR-wqIPmYckh5tIoBaIDBKm7-uE0
# BcNGEjIHcxV
# BcM-m_AlZAJ
# BcM--gBgtQk
# BcM3neoj2I7
# BcM6IMoAmf-
# BcMzaY2nXzT
# BcMzHIrjsO5
# BbLkieODQSM
# BcMWYqPl4RR

# %%
dir(api)
# Out:
# ['API_URL',
#  'EXTERNAL_LOC_SOURCES',
#  'IG_CAPABILITIES',
#  'IG_SIG_KEY',
#  'SIG_KEY_VERSION',
#  'USER_AGENT',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_call_api',
#  '_generate_signature',
#  '_read_response',
#  '_validate_location',
#  'ad_id',
#  'android_release',
#  'android_version',
#  'api_url',
#  'app_version',
#  'authenticated_params',
#  'authenticated_user_id',
#  'authenticated_user_name',
#  'auto_patch',
#  'autocomplete_user_list',
#  'block_friend_reel',
#  'blocked_reels',
#  'blocked_user_list',
#  'broadcast_comment',
#  'broadcast_comments',
# ...

# %%
api.top_search("fishingheya")
# Out:
# {'clear_client_cache': False,
#  'has_more': False,
#  'hashtags': [{'hashtag': {'id': 17843701405017228,
#     'media_count': 11,
#     'name': 'fishingheya'},
#    'position': 1}],
#  'places': [{'place': {'location': {'address': '將軍澳貿業路8號新都城3期地下G19-20 號鋪',
#      'city': '',
#      'external_source': 'facebook_places',
#      'facebook_places_id': 776145745774926,
#      'lat': 22.3223991,
#      'lng': 114.2573624,
#      'name': '漁之部屋',
#      'pk': 555848366,
#      'short_name': '漁之部屋'},
#     'media_bundles': [],
#     'subtitle': '將軍澳貿業路8號新都城3期地下G19-20 號鋪',
#     'title': '漁之部屋'},
#    'position': 0}],
#  'rank_token': '23d8779d-0cd6-4b61-ba82-a5af3d3d1daf',
#  'status': 'ok',
#  'users': []}

# %%
# %load_ext autoreload
# %autoreload 2
import argparse
from csv import DictWriter
import json
import sys

from bs4 import BeautifulSoup
import urllib.request as request
import instagram_private_api, instagram_web_api

# %%
def getHTML(url):
    headers = {'User-Agent': 'User-Agent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'}
    req = request.Request(url, headers=headers)
    return request.urlopen(req).read()

# %%
class ins_api:
    def __init__(self):
        self.topsearchUrl = "https://www.instagram.com/web/search/topsearch/?context=blended&query="
        self.locationExploreUrl = "https://www.instagram.com/explore/locations/"
        user_name = 'jerry_jiarui_xu'
        password = 'xvjiarui'
        self.app_api = instagram_private_api.Client(user_name, password)
        self.web_api = instagram_web_api.Client()
        
    def to_json(self, url):
        return json.loads(getHTML(url))
    def top_search(self, query):
        return self.to_json(self.topsearchUrl+query)
    def get_location_id(self, search_json):
        return search_json['places'][0]['place']['location']['pk']
    def location_search(self, location):
        return self.web_api.location_feed(location_id=location, count=100)
    def total_like(self, location_json):
        ret = 0
        for p in location_json['location']['media']['nodes']:
            ret += p['likes']['count']
        return ret
    def get_like_num(self, query):
        return self.total_like(self.location_search(self.get_location_id(self.top_search(query))))

# %%
ins = ins_api()
# print (ins.top_search("fishingheya"))
print (ins.total_like(ins.location_search(ins.get_location_id(ins.top_search("fishingheya")))))
print (ins.get_like_num("fishingheya"))
# Out:
# 609
# 609

# %%
api.feed_location("555848366", count=10)
# Out:
# {'auto_load_more_enabled': True,
#  'items': [{'can_viewer_save': True,
#    'caption': {'bit_flags': 0,
#     'content_type': 'comment',
#     'created_at': 1511871288,
#     'created_at_utc': 1511871288,
#     'did_report_as_spam': False,
#     'has_translation': True,
#     'media_id': 1658018996271500676,
#     'pk': 17883535378152325,
#     'status': 'Active',
#     'text': '食返肥啲先..😋\n#shunheico29👫',
#     'type': 1,
#     'user': {'friendship_status': {'following': False,
#       'is_bestie': False,
#       'outgoing_request': False},
#      'full_name': 'Co Co/ Ying',
#      'has_anonymous_profile_picture': False,
#      'is_favorite': False,
#      'is_private': False,
#      'is_unpublished': False,
#      'pk': 179626370,
#      'profile_pic_id': '1614519009596422582_179626370',
#      'profile_pic_url': 'https://scontent-hkg3-1.cdninstagram.com/t51.2885-19/s150x150/22069692_1984392181845222_5825653555364626432_n.jpg',
#      'username': 'coco_choy_'},
# ...

# %%
print (items['items'][0]['like_count'])
# Out:
# 22

# %%
len(items['items'])
# Out:
# 6

# %%
web_api = instagram_web_api.Client()

# %%
web_api.location_feed(location_id="555848366", count=50)
# Out:
# {'location': {'directory': {'city': {'id': 'c892789',
#     'name': 'Mau Wu Tsai',
#     'slug': 'mau-wu-tsai'},
#    'country': {'id': 'HK', 'name': 'Hong Kong', 'slug': 'hong-kong'}},
#   'has_public_page': True,
#   'id': '555848366',
#   'lat': 22.3223991,
#   'lng': 114.2573624,
#   'media': {'count': 931,
#    'nodes': [{'caption': '食返肥啲先..😋\n#shunheico29👫',
#      'code': 'BcCd34XnM2E',
#      'comments': {'count': 0},
#      'comments_disabled': False,
#      'date': 1511871288,
#      'dimensions': {'height': 1350, 'width': 1080},
#      'display_src': 'https://scontent-hkg3-1.cdninstagram.com/t51.2885-15/e35/24175693_135583150476439_4686692674449702912_n.jpg',
#      'id': '1658018996271500676',
#      'is_video': False,
#      'likes': {'count': 22},
#      'owner': {'id': '179626370'},
#      'thumbnail_resources': [{'config_height': 150,
#        'config_width': 150,
# ...

# %%
json_ret = web_api.location_feed(location_id="555848366", count=50)

# %%
len(json_ret['location']['media']['nodes'])
# Out:
# 24

# %%
web_api.search("fishingheya")
# Out:
# {'clear_client_cache': False,
#  'has_more': False,
#  'hashtags': [{'hashtag': {'id': 17843701405017228,
#     'media_count': 11,
#     'name': 'fishingheya'},
#    'position': 0}],
#  'places': [],
#  'rank_token': '9c881868-ec56-4a4d-8959-106470373b2e',
#  'status': 'ok',
#  'users': []}

# %%
import csv

# %%
with open("ChineseRestaurant.csv") as f:
    f_csv = csv.DictReader(f)
    for row in f_csv:
        print (row["urlUI"])
# Out:
# /zh/hongkong/r-%E6%A8%82%E5%A4%A9%E7%9A%87%E6%9C%9D-%E9%8A%85%E9%91%BC%E7%81%A3-%E7%B2%B5%E8%8F%9C-%E5%BB%A3%E6%9D%B1-%E4%B8%AD%E5%BC%8F%E5%8C%85%E9%BB%9E-r170063
# /zh/hongkong/r-%E7%A8%8B%E7%8F%AD%E9%95%B7%E5%8F%B0%E7%81%A3%E7%BE%8E%E9%A3%9F-%E8%8D%94%E6%9E%9D%E8%A7%92-%E5%8F%B0%E7%81%A3%E8%8F%9C-%E7%B2%89%E9%BA%B5-%E7%B1%B3%E7%B7%9A-r138997
# /zh/hongkong/r-%E7%99%BE%E6%A8%82%E5%B0%8F%E9%A4%A8-%E5%B0%96%E6%B2%99%E5%92%80-%E6%BD%AE%E5%B7%9E%E8%8F%9C-r185336
# /zh/hongkong/r-%E8%80%81%E9%BB%9E%E9%BB%9E%E5%BF%83%E7%AB%B9%E7%AD%92%E9%A3%AF-%E6%97%BA%E8%A7%92-%E7%B2%B5%E8%8F%9C-%E5%BB%A3%E6%9D%B1-%E9%BB%9E%E5%BF%83-r124481
# /zh/hongkong/r-%E5%94%90%E5%AE%AE%E5%B0%8F%E8%81%9A-%E4%B8%AD%E7%92%B0-%E7%B2%B5%E8%8F%9C-%E5%BB%A3%E6%9D%B1-%E9%BB%9E%E5%BF%83-r185054
# /zh/hongkong/r-%E5%90%8D%E9%A4%A8-%E9%8A%85%E9%91%BC%E7%81%A3-%E5%A4%9A%E5%9C%8B%E8%8F%9C-%E9%BB%9E%E5%BF%83-r478614
# ...

# %%
getHTML("https://www.openrice.com"+"/zh/hongkong/r-%E6%A8%82%E5%A4%A9%E7%9A%87%E6%9C%9D-%E9%8A%85%E9%91%BC%E7%81%A3-%E7%B2%B5%E8%8F%9C-%E5%BB%A3%E6%9D%B1-%E4%B8%AD%E5%BC%8F%E5%8C%85%E9%BB%9E-r170063"+"/reviews")
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="zh-HK" class="or-web">\r\n<head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# website: http://ogp.me/ns/website#">\r\n        <meta charset="utf-8" />\r\n    <title>\xe6\xa8\x82\xe5\xa4\xa9\xe7\x9a\x87\xe6\x9c\x9d\xe7\x9a\x84\xe9\xa3\x9f\xe8\xa9\x95 \xe2\x80\x93 \xe9\xa6\x99\xe6\xb8\xaf\xe9\x8a\x85\xe9\x91\xbc\xe7\x81\xa3\xe5\x88\xa9\xe8\x88\x9e\xe8\x87\xba\xe5\xbb\xa3\xe5\xa0\xb4\xe7\x9a\x84\xe7\xb2\xb5\xe8\x8f\x9c (\xe5\xbb\xa3\xe6\x9d\xb1)\xe4\xb8\xad\xe5\xbc\x8f\xe5\x8c\x85\xe9\xbb\x9e\xe4\xb8\xad\xe8\x8f\x9c\xe9\xa4\xa8 | OpenRice \xe9\xa6\x99\xe6\xb8\xaf\xe9\x96\x8b\xe9\xa3\xaf\xe5\x96\x87</title>\r\n    <meta name="theme-color" content="#ffcb05" />\r\n    <meta name="viewport" content="width=1280" />\r\n            <link rel="dns-prefetch" href="//static5.orstatic.com">\r\n            <link rel="dns-prefetch" href="//static6.orstatic.com">\r\n            <link rel="dns-prefetch" href="//static7.orstatic.com">\r\n            <link r
# ...

# %%
def getReview(urlUI):
    url = "https://www.openrice.com"+urlUI+"/reviews"
    soup = BeautifulSoup(getHTML(url), 'lxml') 
    review_list = [e for e in soup.find_all('section', {'class':"review-container"})]
    review_list = []
    for e in soup.find_all('section', {'class':"review-container"}):
        [x.extract() for x in e.find_all('a')]
        review_list.append("".join(e.stripped_strings))
    return review_list

# %%
test_urlUI = "/zh/hongkong/r-%E6%A8%82%E5%A4%A9%E7%9A%87%E6%9C%9D-%E9%8A%85%E9%91%BC%E7%81%A3-%E7%B2%B5%E8%8F%9C-%E5%BB%A3%E6%9D%B1-%E4%B8%AD%E5%BC%8F%E5%8C%85%E9%BB%9E-r170063"
print (len(getReview(test_urlUI)))
# Out:
# 15
